# %%
import pandas as pd
df=pd.read_csv('anova_IG.csv')
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
df
# Out:
#      mean_per_efficacy  mean_per_trust  B.View of vaccine  C.Non_hesitant
# 0                  4.0             3.7                  0               1
# 1                  3.5             4.0                  2               0
# 2                  3.0             3.7                  0               1
# 3                  3.2             3.7                  0               1
# 4                  2.0             3.0                  2               0
# 5                  2.2             3.0                  0               0
# 6                  3.8             4.0                  0               1
# 7                  4.0             0.0                  0               1
# 8                  2.0             2.7                  2               0
# 9                  4.0             4.0                  0               1
# 10                 3.2             2.7                  2               1
# 11                 3.0             3.0                  0               1
# 12                 3.0             3.7                  0               1
# 13                 2.8             3.3                  2               0
# 14                 2.2             3.3                  2               1
# 15                 2.0             3.0                  2               0
# 16                 3.0             4.0                  2               0
# 17                 3.0             4.0                  2               1
# 18                 3.0             3.3                  0               1
# 19                 2.0             2.0                  2               0
# 20                 2.5             3.0                  0               1
# 21                 3.2             4.0                  2               1
# 22                 2.0             2.3                  2               0
# 23                 3.0             4.0                  0               1
# 24                 2.5             3.3                  2               0
# 25                 1.8             2.3                  1               0
# 26                 3.0             4.0                  2               1
# 27                 3.2             4.0                  0               1
# 28                 3.0             3.0                  0               1
# 29                 1.0             0.7                  2               0
# 30                 3.0             3.3                  0               1
# 31                 3.0             2.0                  2               1
# 32                 2.0             2.0                  2               0
# 33                 3.2             3.7                  0               1
# 34                 3.0             3.7                  0               1
# 35                 2.8             4.0                  0               1
# 36                 2.8             2.0                  0               1
# 37                 3.8             4.0                  0               1
# 38                 3.0             4.0                  0               1
# 39                 3.2             1.3                  2               1
# 40                 4.0             4.0                  1               1
# 41                 3.5             3.3                  0               1
# 42                 2.5             4.0                  0               0
# 43                 4.0             3.3                  0               1
# 44                 0.5             2.0                  1               0
# 45                 2.0             3.3                  2               0
# 46                 4.0             4.0                  0               1
# 47                 3.8             4.0                  0               1
# 48                 3.8             3.7                  0               1
# 49                 4.0             4.0                  0               1
# 50                 3.0             1.0                  2               0
# 51                 2.0             2.0                  2               0
# 52                 3.0             3.0                  0               1
# 53                 0.0             1.3                  1               0
# 54                 3.0             3.3                  2               1
# 55                 4.0             3.3                  0               1
# 56                 2.5             3.3                  2               0
# 57                 0.0             2.7                  1               0
# 58                 2.0             3.7                  2               0
# 59                 2.0             2.3                  0               0
# 60                 3.0             3.0                  0               1
# 61                 3.2             3.7                  0               1
# 62                 2.8             4.0                  0               0
# 63                 3.5             4.0                  1               1
# 64                 2.2             1.7                  0               0
# 65                 3.5             2.3                  0               1
# 66                 3.2             3.3                  0               0
# 67                 2.8             3.7                  0               0
# 68                 3.0             4.0                  2               1
# 69                 4.0             3.7                  0               1
# 70                 3.0             4.0                  0               1
# 71                 3.5             3.7                  2               1
# 72                 2.0             2.0                  2               0
# 73                 2.2             2.7                  0               0
# 74                 3.5             4.0                  0               1
# 75                 3.8             3.7                  0               1
# 76                 3.0             2.3                  2               0
# 77                 3.0             1.0                  0               1
# 78                 2.8             2.3                  2               0
# 79                 4.0             4.0                  0               1
# 80                 3.8             3.7                  0               1
# 81                 4.0             4.0                  0               1
# 82                 4.0             4.0                  0               1
# 83                 3.0             3.0                  0               0
# 84                 3.8             4.0                  0               1
# 85                 2.5             2.7                  2               0
# 86                 4.0             4.0                  0               1
# 87                 2.8             3.3                  0               1
# 88                 3.0             4.0                  2               1
# 89                 2.8             3.3                  0               1
# 90                 4.0             4.0                  0               1
# 91                 3.0             1.0                  0               1
# 92                 3.0             3.7                  0               1
# 93                 3.8             4.0                  0               1
# 94                 3.2             4.0                  0               1
# 95                 4.0             3.3                  0               1
# 96                 3.8             3.3                  0               1
# 97                 3.0             2.0                  0               1
# 98                 3.0             2.7                  2               0
# 99                 3.0             3.3                  0               1
# 100                3.5             4.0                  0               1
# 101                3.0             4.0                  0               1
# 102                3.2             2.7                  0               1
# 103                2.8             2.3                  2               1
# 104                1.8             2.7                  0               0
# 105                3.0             3.0                  0               1
# 106                2.8             3.0                  2               1
# 107                3.0             4.0                  0               1
# 108                2.8             4.0                  0               1
# 109                2.8             3.0                  0               0
# 110                3.2             1.7                  1               0
# 111                3.5             4.0                  0               1
# 112                4.0             4.0                  0               1
# 113                3.0             3.0                  0               1
# 114                2.0             2.7                  0               1
# 115                3.5             4.0                  0               0
# 116                2.2             4.0                  0               1
# 117                3.0             3.7                  0               1
# 118                2.0             2.0                  2               0
# 119                2.5             4.0                  2               0
# 120                2.0             2.0                  1               0
# 121                1.0             1.3                  1               0
# 122                0.0             3.7                  1               0
# 123                4.0             0.0                  1               1
# 124                2.0             2.0                  2               1
# 125                3.0             2.3                  1               1
# 126                2.8             2.3                  2               0
# 127                2.8             2.3                  0               0
# 128                2.5             3.0                  0               1
# 129                4.0             3.0                  0               1
# 130                2.0             2.0                  1               0
# 131                0.5             2.0                  1               0
# 132                2.5             1.7                  0               1
# 133                1.2             1.3                  2               0
# 134                2.8             3.0                  0               1
# 135                2.2             2.7                  1               0
# 136                2.5             3.3                  0               1
# 137                3.0             3.3                  0               1
# 138                3.0             2.7                  1               1
# 139                2.0             3.0                  1               0
# 140                2.2             2.3                  0               1
# 141                2.8             2.0                  2               0
# 142                1.8             2.3                  2               0
# 143                2.2             4.0                  1               1
# 144                2.8             3.0                  2               0
# 145                3.0             2.7                  0               1
# 146                1.8             2.3                  1               0
# 147                1.8             3.0                  1               0
# 148                1.8             2.0                  2               0
# 149                2.2             2.0                  1               0
# 150                2.5             2.7                  1               0
# 151                1.8             2.3                  2               0
# 152                1.5             2.3                  1               0
# 153                2.0             2.3                  2               0
# 154                2.8             3.0                  2               0
# 155                2.2             2.0                  2               1
# 156                2.5             2.0                  0               0
# 157                4.0             2.7                  0               1
# 158                4.0             1.3                  1               1
# 159                2.0             4.0                  2               0
# 160                4.0             4.0                  0               1
# 161                3.0             4.0                  0               1
# 162                2.8             3.0                  2               1
# 163                4.0             3.0                  0               1
# 164                2.0             2.0                  1               0
# 165                2.0             2.0                  0               0
# 166                1.8             2.0                  0               0
# 167                2.2             4.0                  2               0
# 168                3.2             3.3                  0               1
# 169                2.0             2.3                  2               0
# 351                2.2             2.3                  1               1
# 352                3.0             4.0                  0               1
# 353                3.5             4.0                  0               1
# 354                2.5             3.3                  0               0
# 355                4.0             4.0                  0               1
# 356                2.2             3.3                  2               1
# 357                3.2             4.0                  0               1
# 358                3.2             2.0                  0               1
# 359                1.8             3.3                  2               0
# 360                3.0             4.0                  0               1
# 361                2.2             2.0                  2               0
# 362                2.8             2.7                  2               0
# 363                3.2             4.0                  0               1
# 364                3.2             2.0                  2               1
# 365                2.0             2.0                  2               0
# 366                3.8             4.0                  0               1
# 367                3.2             2.3                  0               1
# 368                2.2             2.7                  2               0
# 369                2.5             4.0                  2               1
# 370                3.0             2.7                  2               1
# 371                2.0             2.3                  2               0
# 372                4.0             4.0                  0               1
# 373                3.0             2.3                  0               0
# 374                3.0             2.7                  0               1
# 375                2.0             2.0                  0               0
# 376                2.8             3.0                  0               1
# 377                3.2             3.7                  2               1
# 378                3.5             3.3                  0               1
# 379                3.0             3.7                  0               1
# 380                3.0             3.7                  0               0
# 381                2.8             3.3                  2               1
# 382                3.0             4.0                  0               1
# 383                2.2             3.3                  1               0
# 384                3.0             4.0                  0               1
# 385                4.0             4.0                  0               1
# 386                1.8             2.3                  2               0
# 387                3.8             2.3                  0               1
# 388                2.8             2.0                  2               1
# 389                4.0             3.7                  0               1
# 390                4.0             3.7                  0               1
# 391                1.8             1.7                  2               0
# 392                2.8             3.7                  0               1
# 393                2.8             4.0                  2               0
# 394                3.0             3.0                  0               1
# 395                3.5             3.7                  0               1
# 396                2.8             2.7                  1               1
# 397                4.0             4.0                  0               1
# 398                3.0             3.0                  1               1
# 399                4.0             4.0                  0               1
# 400                3.8             4.0                  0               1
# 401                3.0             2.0                  0               0
# 402                3.0             4.0                  0               1
# 403                2.5             2.7                  2               0
# 404                4.0             4.0                  0               1
# 405                3.5             4.0                  0               1
# 406                3.0             3.3                  2               1
# 407                3.2             4.0                  0               1
# 408                4.0             3.0                  0               1
# 409                3.5             3.3                  0               1
# 410                3.0             2.7                  0               1
# 411                2.2             2.7                  1               0
# 412                3.8             3.3                  0               1
# 413                4.0             4.0                  2               1
# 414                3.8             4.0                  0               1
# 415                0.5             2.0                  1               0
# 416                3.8             4.0                  0               1
# 417                3.0             2.7                  0               0
# 418                2.5             3.3                  1               0
# 419                3.8             4.0                  2               1
# 420                2.2             2.7                  2               1
# 421                2.8             3.0                  0               1
# 422                2.0             2.0                  1               0
# 423                1.8             2.3                  2               0
# 424                4.0             2.7                  0               1
# 425                2.8             4.0                  0               1
# 426                2.5             3.7                  0               1
# 427                4.0             4.0                  0               1
# 428                4.0             0.0                  2               1
# 429                2.2             2.7                  0               0
# 430                3.2             4.0                  0               1
# 431                3.5             2.7                  0               1
# 432                2.8             4.0                  0               0
# 433                3.5             1.3                  0               0
# 434                2.8             2.7                  0               1
# 435                1.8             2.0                  2               0
# 436                3.5             4.0                  0               1
# 437                4.0             4.0                  0               1
# 438                0.0             1.3                  1               0
# 439                3.8             3.7                  0               1
# 440                2.2             3.3                  2               1
# 441                0.0             3.3                  2               0
# 532                2.5             2.3                  2               0
# 533                2.0             1.7                  1               0
# 534                2.5             2.7                  0               0
# 535                3.0             2.7                  0               1
# 536                2.0             2.0                  2               0
# 537                2.2             2.0                  1               0
# 538                2.8             2.7                  0               1
# 539                2.0             4.0                  0               0
# 540                2.8             2.7                  0               0
# 541                2.0             2.7                  0               0
# 542                3.0             3.0                  0               1
# 543                2.0             2.0                  0               0
# 544                2.0             2.7                  0               0
# 545                2.2             1.7                  0               0
# 546                2.8             2.3                  2               1
# 547                2.2             2.3                  2               0
# 548                3.0             1.0                  1               1
# 549                2.0             2.0                  2               0
# 550                3.8             4.0                  0               1
# 551                2.8             2.7                  2               1
# 552                3.5             1.7                  0               1
# 553                3.5             2.3                  2               1

# %%
import warnings
import numpy as np

# Suppress overflow warning
warnings.filterwarnings("ignore", category=RuntimeWarning)
np.seterr(over='ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
target=df["C.Non_hesitant"]
features=df.drop('C.Non_hesitant',axis=1)

# %%
# Split data into train and test sets

# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split the dataset into training + development set and test set
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 0)

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Random Forest Bagging
model_bagging_rf = BaggingClassifier(estimator=RandomForestClassifier(), n_estimators=10, random_state=7)

# Cross-validation
print("Model: Random Forest")
scores_rf = cross_val_score(model_bagging_rf, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_rf)
print("Mean Accuracy (Validation):", scores_rf.mean())
print("-" * 50)

# Test set evaluation
model_bagging_rf.fit(x_train, y_train)
test_predict_rf = model_bagging_rf.predict(x_test)
print("Random Forest Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_rf))
print("=" * 50)
# Out:
# Model: Random Forest
# Accuracy scores for each fold:  [0.85393258 0.79775281 0.80898876 0.85227273 0.85227273]
# Mean Accuracy (Validation): 0.8330439223697651
# --------------------------------------------------
# Random Forest Bagging - Accuracy (Test): 0.8918918918918919
# ==================================================

# %% [markdown]
# # BAGGING

# %% [markdown]
# NN

# %%
# Import necessary libraries
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Neural Network with one hidden layer of 5 neurons
model_bagging_nn = BaggingClassifier(
    estimator=MLPClassifier(hidden_layer_sizes=(5,10), max_iter=200, random_state=7), 
    n_estimators=10, 
    random_state=7
)

# Cross-validation
print("Model: Neural Network (5 neurons in the hidden layer)")
scores_nn = cross_val_score(model_bagging_nn, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_nn)
print("Mean Accuracy (Validation):", scores_nn.mean())
print("-" * 50)

# Test set evaluation
model_bagging_nn.fit(x_train, y_train)
test_predict_nn = model_bagging_nn.predict(x_test)
print("Neural Network Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_nn))
print("=" * 50)
# Out:
# Model: Neural Network (5 neurons in the hidden layer)
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Accuracy scores for each fold:  [0.7752809  0.75280899 0.75280899 0.75       0.86363636]
# Mean Accuracy (Validation): 0.7789070480081717
# --------------------------------------------------
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Neural Network Bagging - Accuracy (Test): 0.8468468468468469
# ==================================================
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Linear SVM Bagging (with probability=True for flexibility)
model_bagging_linear_svm = BaggingClassifier(
    estimator=SVC(kernel='linear', C=0.1, probability=True),
    n_estimators=10,
    random_state=7
)

# Cross-validation
print("Model: Linear SVM (C=0.1)")
scores_linear_svm = cross_val_score(model_bagging_linear_svm, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold:", scores_linear_svm)
print("Mean Accuracy (Validation):", scores_linear_svm.mean())
print("-" * 50)

# Test set evaluation
model_bagging_linear_svm.fit(x_train, y_train)
test_predict_linear_svm = model_bagging_linear_svm.predict(x_test)
print("Linear SVM Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_linear_svm))
print("=" * 50)
# Out:
# Model: Linear SVM (C=0.1)
# Accuracy scores for each fold: [0.84269663 0.88764045 0.84269663 0.84090909 0.88636364]
# Mean Accuracy (Validation): 0.8600612870275791
# --------------------------------------------------
# Linear SVM Bagging - Accuracy (Test): 0.8648648648648649
# ==================================================

# %%
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Polynomial SVM Bagging (with probability=True for flexibility)
model_bagging_poly_svm = BaggingClassifier(
    estimator=SVC(kernel='poly', C=1, degree=3, gamma='scale', probability=True),
    n_estimators=10,
    random_state=7
)

# Cross-validation
print("Model: Polynomial SVM (C=1, degree=3)")
scores_poly_svm = cross_val_score(model_bagging_poly_svm, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold:", scores_poly_svm)
print("Mean Accuracy (Validation):", scores_poly_svm.mean())
print("-" * 50)

# Fit and Test evaluation
model_bagging_poly_svm.fit(x_train, y_train)
test_predict_poly_svm = model_bagging_poly_svm.predict(x_test)
print("Polynomial SVM Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_poly_svm))
print("=" * 50)
# Out:
# Model: Polynomial SVM (C=1, degree=3)
# Accuracy scores for each fold: [0.83146067 0.88764045 0.82022472 0.85227273 0.875     ]
# Mean Accuracy (Validation): 0.8533197139938713
# --------------------------------------------------
# Polynomial SVM Bagging - Accuracy (Test): 0.8648648648648649
# ==================================================

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# RBF SVM Bagging (with probability=True for flexibility)
model_bagging_rbf_svm = BaggingClassifier(
    estimator=SVC(kernel='rbf', C=10, gamma='scale', probability=True),
    n_estimators=10,
    random_state=7
)

# Cross-validation
print("Model: RBF SVM (C=10, gamma='scale')")
scores_rbf_svm = cross_val_score(model_bagging_rbf_svm, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold:", scores_rbf_svm)
print("Mean Accuracy (Validation):", scores_rbf_svm.mean())
print("-" * 50)

# Test set evaluation
model_bagging_rbf_svm.fit(x_train, y_train)
test_predict_rbf_svm = model_bagging_rbf_svm.predict(x_test)
print("RBF SVM Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_rbf_svm))
print("=" * 50)
# Out:
# Model: RBF SVM (C=10, gamma='scale')
# Accuracy scores for each fold: [0.84269663 0.85393258 0.83146067 0.84090909 0.86363636]
# Mean Accuracy (Validation): 0.8465270684371807
# --------------------------------------------------
# RBF SVM Bagging - Accuracy (Test): 0.8648648648648649
# ==================================================

# %% [markdown]
# # Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np

# Define the Gradient Boosting classifier
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Cross-validation
cv_scores = cross_val_score(gbc, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold (CV): ", cv_scores)
print("Mean Accuracy (Validation): {:.4f}".format(cv_scores.mean()))
print("-" * 50)

# Fit the model on the full training data
gbc.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred = gbc.predict(x_test)
accuracy = accuracy_score(y_test, y_test_pred)

# Print evaluation metrics
print(f'Accuracy (Test): {accuracy:.4f}')
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred))
print('Classification Report:')
print(classification_report(y_test, y_test_pred))
print("=" * 50)
# Out:
# Accuracy scores for each fold (CV):  [0.85393258 0.79775281 0.80898876 0.82954545 0.81818182]
# Mean Accuracy (Validation): 0.8217
# --------------------------------------------------
# Accuracy (Test): 0.8559
# Confusion Matrix:
# [[40  5]
#  [11 55]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.78      0.89      0.83        45
#            1       0.92      0.83      0.87        66
#
#     accuracy                           0.86       111
#    macro avg       0.85      0.86      0.85       111
# weighted avg       0.86      0.86      0.86       111
#
# ==================================================

# %%
import xgboost as xgb
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np

# Define the XGBoost classifier
xgb_clf = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Cross-validation
cv_scores = cross_val_score(xgb_clf, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold (CV): ", cv_scores)
print("Mean Accuracy (Validation): {:.4f}".format(cv_scores.mean()))
print("-" * 50)

# Fit the model on the full training data
xgb_clf.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred = xgb_clf.predict(x_test)
accuracy = accuracy_score(y_test, y_test_pred)

# Print evaluation metrics
print(f'Accuracy (Test): {accuracy:.4f}')
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred))
print('Classification Report:')
print(classification_report(y_test, y_test_pred))
print("=" * 50)
# Out:
# Accuracy scores for each fold (CV):  [0.83146067 0.82022472 0.82022472 0.84090909 0.85227273]
# Mean Accuracy (Validation): 0.8330
# --------------------------------------------------
# Accuracy (Test): 0.8649
# Confusion Matrix:
# [[40  5]
#  [10 56]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.80      0.89      0.84        45
#            1       0.92      0.85      0.88        66
#
#     accuracy                           0.86       111
#    macro avg       0.86      0.87      0.86       111
# weighted avg       0.87      0.86      0.87       111
#
# ==================================================

# %% [markdown]
# # ADABOOSTING

# %% [markdown]
# rbf

# %%
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Define the RBF SVM base estimator with updated parameters
rbf_svm = SVC(kernel='rbf', probability=True, C=10, gamma='scale', random_state=7)

# AdaBoost with RBF SVM
ada_rbf_svm = AdaBoostClassifier(estimator=rbf_svm, n_estimators=10, random_state=7)

# Cross-validation
cv_scores_rbf_svm = cross_val_score(ada_rbf_svm, x_train, y_train, cv=5, scoring='accuracy')
print("RBF SVM - Accuracy scores for each fold (CV): ", cv_scores_rbf_svm)
print("RBF SVM - Mean Accuracy (Validation): {:.4f}".format(cv_scores_rbf_svm.mean()))
print("-" * 50)

# Fit the model on the full training data
ada_rbf_svm.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred_rbf_svm = ada_rbf_svm.predict(x_test)
accuracy_rbf_svm = accuracy_score(y_test, y_test_pred_rbf_svm)

# Print evaluation metrics
print(f'RBF SVM - Accuracy (Test): {accuracy_rbf_svm:.4f}')
print('RBF SVM - Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred_rbf_svm))
print('RBF SVM - Classification Report:')
print(classification_report(y_test, y_test_pred_rbf_svm))
print("=" * 50)
# Out:
# RBF SVM - Accuracy scores for each fold (CV):  [0.78651685 0.79775281 0.78651685 0.77272727 0.85227273]
# RBF SVM - Mean Accuracy (Validation): 0.7992
# --------------------------------------------------
# RBF SVM - Accuracy (Test): 0.8468
# RBF SVM - Confusion Matrix:
# [[40  5]
#  [12 54]]
# RBF SVM - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.89      0.82        45
#            1       0.92      0.82      0.86        66
#
#     accuracy                           0.85       111
#    macro avg       0.84      0.85      0.84       111
# weighted avg       0.86      0.85      0.85       111
#
# ==================================================

# %%
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Define the Linear SVM base estimator with updated parameters
linear_svm = SVC(kernel='linear', probability=True, C=0.1, random_state=7)

# AdaBoost with Linear SVM
ada_linear_svm = AdaBoostClassifier(estimator=linear_svm, n_estimators=10, random_state=7)

# Cross-validation
cv_scores_linear_svm = cross_val_score(ada_linear_svm, x_train, y_train, cv=5, scoring='accuracy')
print("Linear SVM - Accuracy scores for each fold (CV): ", cv_scores_linear_svm)
print("Linear SVM - Mean Accuracy (Validation): {:.4f}".format(cv_scores_linear_svm.mean()))
print("-" * 50)

# Fit the model on the full training data
ada_linear_svm.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred_linear_svm = ada_linear_svm.predict(x_test)
accuracy_linear_svm = accuracy_score(y_test, y_test_pred_linear_svm)

# Print evaluation metrics
print(f'Linear SVM - Accuracy (Test): {accuracy_linear_svm:.4f}')
print('Linear SVM - Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred_linear_svm))
print('Linear SVM - Classification Report:')
print(classification_report(y_test, y_test_pred_linear_svm))
print("=" * 50)
# Out:
# Linear SVM - Accuracy scores for each fold (CV):  [0.57303371 0.57303371 0.57303371 0.57954545 0.57954545]
# Linear SVM - Mean Accuracy (Validation): 0.5756
# --------------------------------------------------
# Linear SVM - Accuracy (Test): 0.5946
# Linear SVM - Confusion Matrix:
# [[ 0 45]
#  [ 0 66]]
# Linear SVM - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        45
#            1       0.59      1.00      0.75        66
#
#     accuracy                           0.59       111
#    macro avg       0.30      0.50      0.37       111
# weighted avg       0.35      0.59      0.44       111
#
# ==================================================
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1565: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Define the Polynomial SVM base estimator
poly_svm = SVC(kernel='poly', C=1, degree=3, gamma='scale', probability=True, random_state=7)

# AdaBoost with Polynomial SVM
ada_poly_svm = AdaBoostClassifier(estimator=poly_svm, n_estimators=10, random_state=7)

# Cross-validation
cv_scores_poly_svm = cross_val_score(ada_poly_svm, x_train, y_train, cv=5, scoring='accuracy')
print("Polynomial SVM - Accuracy scores for each fold (CV): ", cv_scores_poly_svm)
print("Polynomial SVM - Mean Accuracy (Validation): {:.4f}".format(cv_scores_poly_svm.mean()))
print("-" * 50)

# Fit the model on the full training data
ada_poly_svm.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred_poly_svm = ada_poly_svm.predict(x_test)
accuracy_poly_svm = accuracy_score(y_test, y_test_pred_poly_svm)

# Print evaluation metrics
print(f'Polynomial SVM - Accuracy (Test): {accuracy_poly_svm:.4f}')
print('Polynomial SVM - Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred_poly_svm))
print('Polynomial SVM - Classification Report:')
print(classification_report(y_test, y_test_pred_poly_svm))
print("=" * 50)
# Out:
# Polynomial SVM - Accuracy scores for each fold (CV):  [0.84269663 0.83146067 0.83146067 0.80681818 0.85227273]
# Polynomial SVM - Mean Accuracy (Validation): 0.8329
# --------------------------------------------------
# Polynomial SVM - Accuracy (Test): 0.8559
# Polynomial SVM - Confusion Matrix:
# [[41  4]
#  [12 54]]
# Polynomial SVM - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.77      0.91      0.84        45
#            1       0.93      0.82      0.87        66
#
#     accuracy                           0.86       111
#    macro avg       0.85      0.86      0.85       111
# weighted avg       0.87      0.86      0.86       111
#
# ==================================================

# %%
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# KNN (k=23) - Bagging only
model_bagging_knn = BaggingClassifier(
    estimator=KNeighborsClassifier(n_neighbors=9),
    n_estimators=10,
    random_state=7
)
print("Model: KNN (k=23) - Bagging")
scores = cross_val_score(model_bagging_knn, x_train, y_train, cv=5, scoring='accuracy')
print("Validation Accuracy:", scores.mean())
model_bagging_knn.fit(x_train, y_train)
print("Test Accuracy:", metrics.accuracy_score(y_test, model_bagging_knn.predict(x_test)))
print("=" * 50)

# Decision Tree (depth=4) - Bagging
model_bagging_dt = BaggingClassifier(
    estimator=DecisionTreeClassifier(max_depth=3, random_state=7),
    n_estimators=10,
    random_state=7
)
print("Model: Decision Tree (depth=4) - Bagging")
scores = cross_val_score(model_bagging_dt, x_train, y_train, cv=5, scoring='accuracy')
print("Validation Accuracy:", scores.mean())
model_bagging_dt.fit(x_train, y_train)
print("Test Accuracy:", metrics.accuracy_score(y_test, model_bagging_dt.predict(x_test)))
print("=" * 50)

# Decision Tree (depth=4) - AdaBoost
model_adaboost_dt = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=3, random_state=7),
    n_estimators=50,
    random_state=7
)
print("Model: Decision Tree (depth=3) - AdaBoost")
scores = cross_val_score(model_adaboost_dt, x_train, y_train, cv=5, scoring='accuracy')
print("Validation Accuracy:", scores.mean())
model_adaboost_dt.fit(x_train, y_train)
print("Test Accuracy:", metrics.accuracy_score(y_test, model_adaboost_dt.predict(x_test)))
print("=" * 50)

# MultinomialNB - Bagging only
model_bagging_mnb = BaggingClassifier(
    estimator=MultinomialNB(),
    n_estimators=10,
    random_state=7
)
print("Model: MultinomialNB - Bagging")
scores = cross_val_score(model_bagging_mnb, x_train, y_train, cv=5, scoring='accuracy')
print("Validation Accuracy:", scores.mean())
model_bagging_mnb.fit(x_train, y_train)
print("Test Accuracy:", metrics.accuracy_score(y_test, model_bagging_mnb.predict(x_test)))
print("=" * 50)
# Out:
# Model: KNN (k=23) - Bagging
# Validation Accuracy: 0.8374872318692542
# Test Accuracy: 0.8648648648648649
# ==================================================
# Model: Decision Tree (depth=4) - Bagging
# Validation Accuracy: 0.842032686414709
# Test Accuracy: 0.8648648648648649
# ==================================================
# Model: Decision Tree (depth=3) - AdaBoost
# Validation Accuracy: 0.8398365679264556
# Test Accuracy: 0.8378378378378378
# ==================================================
# Model: MultinomialNB - Bagging
# Validation Accuracy: 0.7585801838610828
# Test Accuracy: 0.8018018018018018
# ==================================================
