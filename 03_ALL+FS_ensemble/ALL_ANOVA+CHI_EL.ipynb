# %%
import pandas as pd
df=pd.read_csv('anova_chi.csv')
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows',None)
df
# Out:
#      D.Vaccine Protection Perception  D.Side Effect Confidence  \
# 0                                  4                         4
# 1                                  4                         4
# 2                                  3                         3
# 3                                  4                         3
# 4                                  2                         2
# 5                                  3                         2
# 6                                  4                         4
# 7                                  4                         4
# 8                                  2                         2
# 9                                  4                         4
# 10                                 4                         3
# 11                                 4                         3
# 12                                 3                         3
# 13                                 3                         3
# 14                                 3                         3
# 15                                 3                         2
# 16                                 3                         3
# 17                                 4                         2
# 18                                 4                         3
# 19                                 2                         2
# 20                                 3                         3
# 21                                 4                         4
# 22                                 2                         2
# 23                                 3                         3
# 24                                 3                         3
# 25                                 2                         1
# 26                                 3                         3
# 27                                 4                         4
# 28                                 3                         3
# 29                                 1                         1
# 30                                 3                         3
# 31                                 3                         3
# 32                                 2                         2
# 33                                 3                         4
# 34                                 3                         3
# 35                                 3                         3
# 36                                 3                         3
# 37                                 4                         4
# 38                                 3                         3
# 39                                 3                         3
# 40                                 4                         4
# 41                                 4                         3
# 42                                 3                         3
# 43                                 4                         4
# 44                                 2                         0
# 45                                 2                         2
# 46                                 4                         4
# 47                                 4                         4
# 48                                 4                         4
# 49                                 4                         4
# 50                                 3                         3
# 51                                 2                         2
# 52                                 3                         3
# 53                                 0                         0
# 54                                 4                         3
# 55                                 4                         4
# 56                                 3                         3
# 57                                 0                         0
# 58                                 3                         2
# 59                                 3                         2
# 60                                 3                         3
# 61                                 3                         3
# 62                                 3                         3
# 63                                 4                         4
# 64                                 3                         2
# 65                                 4                         3
# 66                                 4                         3
# 67                                 3                         3
# 68                                 4                         3
# 69                                 4                         4
# 70                                 3                         3
# 71                                 4                         4
# 72                                 2                         2
# 73                                 2                         3
# 74                                 4                         3
# 75                                 4                         4
# 76                                 3                         3
# 77                                 3                         3
# 78                                 3                         3
# 79                                 4                         4
# 80                                 4                         4
# 81                                 4                         4
# 82                                 4                         4
# 83                                 3                         3
# 84                                 4                         4
# 85                                 3                         3
# 86                                 4                         4
# 87                                 4                         3
# 88                                 4                         3
# 89                                 3                         3
# 90                                 4                         4
# 91                                 3                         3
# 92                                 3                         3
# 93                                 4                         4
# 94                                 4                         3
# 95                                 4                         4
# 96                                 4                         4
# 97                                 4                         2
# 98                                 3                         3
# 99                                 3                         3
# 100                                3                         4
# 101                                3                         3
# 102                                3                         3
# 103                                3                         2
# 104                                3                         2
# 105                                3                         3
# 106                                3                         3
# 107                                3                         3
# 108                                3                         3
# 109                                3                         3
# 110                                4                         4
# 111                                4                         3
# 112                                4                         4
# 113                                3                         3
# 114                                2                         2
# 115                                4                         4
# 116                                3                         3
# 117                                3                         3
# 118                                2                         2
# 119                                3                         3
# 120                                2                         2
# 121                                1                         1
# 122                                0                         0
# 123                                4                         4
# 124                                2                         2
# 125                                3                         3
# 126                                3                         3
# 127                                3                         3
# 128                                2                         3
# 129                                4                         4
# 130                                2                         2
# 131                                1                         0
# 132                                3                         3
# 133                                1                         1
# 134                                3                         3
# 135                                2                         3
# 136                                3                         3
# 137                                3                         3
# 138                                4                         3
# 139                                3                         2
# 140                                3                         3
# 141                                3                         2
# 142                                2                         2
# 143                                2                         2
# 144                                3                         3
# 145                                3                         3
# 146                                3                         2
# 147                                2                         2
# 148                                2                         2
# 149                                3                         2
# 150                                3                         3
# 151                                2                         2
# 152                                2                         1
# 153                                2                         2
# 154                                4                         3
# 155                                3                         2
# 156                                3                         3
# 157                                4                         4
# 158                                4                         4
# 159                                2                         3
# 160                                4                         4
# 161                                3                         3
# 162                                3                         3
# 163                                4                         4
# 164                                2                         2
# 165                                2                         2
# 166                                2                         2
# 167                                2                         3
# 168                                3                         3
# 169                                2                         2
# 170                                2                         2
# 171                                2                         2
# 172                                3                         1
# 173                                2                         2
# 174                                3                         3
# 175                                2                         2
# 176                                2                         2
# 177                                3                         3
# 178                                2                         2
# 179                                2                         2
# 180                                3                         3
# 181                                4                         4
# 182                                3                         2
# 183                                2                         2
# 184                                4                         3
# 185                                3                         3
# 186                                2                         2
# 187                                3                         3
# 188                                4                         4
# 189                                2                         1
# 190                                2                         2
# 191                                3                         3
# 192                                3                         2
# 193                                3                         3
# 194                                3                         1
# 195                                3                         3
# 196                                3                         3
# 197                                2                         2
# 198                                4                         4
# 199                                2                         4
# 200                                3                         3
# 201                                3                         3
# 202                                4                         4
# 203                                2                         3
# 204                                4                         4
# 205                                3                         3
# 206                                3                         2
# 207                                3                         3
# 208                                2                         2
# 209                                3                         2
# 210                                2                         1
# 211                                3                         3
# 212                                4                         4
# 213                                3                         3
# 214                                3                         3
# 215                                3                         2
# 216                                4                         2
# 217                                3                         3
# 218                                3                         3
# 219                                3                         3
# 220                                2                         2
# 221                                2                         2
# 222                                4                         3
# 223                                3                         2
# 224                                3                         3
# 225                                4                         2
# 226                                2                         2
# 227                                3                         2
# 228                                2                         2
# 229                                3                         3
# 230                                2                         3
# 231                                4                         4
# 232                                2                         2
# 233                                2                         2
# 234                                0                         0
# 235                                2                         2
# 236                                4                         4
# 237                                4                         4
# 238                                4                         3
# 239                                4                         4
# 240                                3                         3
# 241                                3                         3
# 242                                4                         3
# 243                                1                         1
# 244                                2                         2
# 245                                4                         4
# 246                                3                         3
# 247                                4                         4
# 248                                4                         4
# 249                                3                         1
# 250                                2                         2
# 251                                4                         4
# 252                                4                         4
# 253                                4                         4
# 254                                3                         3
# 255                                3                         3
# 256                                4                         4
# 257                                4                         4
# 258                                3                         2
# 259                                3                         3
# 260                                3                         3
# 261                                4                         4
# 262                                3                         3
# 263                                3                         3
# 264                                4                         4
# 265                                4                         4
# 266                                2                         2
# 267                                4                         4
# 268                                4                         4
# 269                                4                         3
# 270                                4                         4
# 271                                4                         3
# 272                                0                         0
# 273                                4                         4
# 274                                4                         3
# 275                                4                         4
# 276                                3                         3
# 277                                3                         2
# 278                                4                         3
# 279                                3                         3
# 280                                2                         2
# 281                                3                         2
# 282                                4                         4
# 283                                3                         3
# 284                                2                         2
# 285                                4                         4
# 286                                3                         4
# 287                                3                         3
# 288                                2                         2
# 289                                2                         2
# 290                                0                         0
# 291                                4                         4
# 292                                3                         3
# 293                                3                         3
# 294                                4                         4
# 295                                1                         1
# 296                                4                         3
# 297                                1                         2
# 298                                3                         3
# 299                                4                         4
# 300                                4                         3
# 301                                3                         3
# 302                                3                         3
# 303                                4                         4
# 304                                3                         1
# 305                                2                         2
# 306                                3                         3
# 307                                3                         3
# 308                                4                         4
# 309                                4                         3
# 310                                4                         3
# 311                                3                         3
# 312                                4                         3
# 313                                4                         4
# 314                                4                         4
# 315                                4                         4
# 316                                3                         3
# 317                                3                         3
# 318                                4                         3
# 319                                2                         2
# 320                                2                         2
# 321                                4                         4
# 322                                3                         3
# 323                                3                         1
# 324                                4                         4
# 325                                3                         3
# 326                                4                         4
# 327                                1                         1
# 328                                4                         4
# 329                                3                         3
# 330                                4                         4
# 331                                3                         3
# 332                                3                         4
# 333                                4                         4
# 334                                3                         3
# 335                                4                         4
# 336                                1                         1
# 337                                2                         2
# 338                                4                         4
# 339                                3                         2
# 340                                2                         3
# 341                                2                         2
# 342                                0                         0
# 343                                3                         3
# 344                                0                         0
# 345                                4                         4
# 346                                0                         0
# 347                                4                         4
# 348                                0                         0
# 349                                3                         2
# 350                                3                         3
# 351                                2                         2
# 352                                3                         3
# 353                                4                         4
# 354                                3                         3
# 355                                4                         4
# 356                                2                         3
# 357                                4                         3
# 358                                4                         3
# 359                                3                         2
# 360                                3                         3
# 361                                3                         3
# 362                                3                         3
# 363                                4                         3
# 364                                3                         2
# 365                                2                         2
# 366                                4                         4
# 367                                3                         4
# 368                                3                         2
# 369                                3                         2
# 370                                3                         3
# 371                                2                         2
# 372                                4                         4
# 373                                3                         3
# 374                                3                         3
# 375                                2                         2
# 376                                4                         2
# 377                                4                         4
# 378                                4                         4
# 379                                4                         4
# 380                                3                         3
# 381                                3                         3
# 382                                3                         3
# 383                                3                         3
# 384                                4                         4
# 385                                4                         4
# 386                                3                         3
# 387                                4                         4
# 388                                3                         3
# 389                                4                         4
# 390                                4                         4
# 391                                2                         2
# 392                                3                         3
# 393                                4                         2
# 394                                4                         3
# 395                                4                         4
# 396                                3                         3
# 397                                4                         4
# 398                                3                         3
# 399                                4                         4
# 400                                4                         4
# 401                                3                         3
# 402                                3                         3
# 403                                3                         2
# 404                                4                         4
# 405                                4                         4
# 406                                3                         3
# 407                                4                         3
# 408                                4                         4
# 409                                4                         3
# 410                                4                         4
# 411                                3                         2
# 412                                4                         4
# 413                                4                         4
# 414                                4                         4
# 415                                0                         0
# 416                                4                         4
# 417                                3                         3
# 418                                3                         2
# 419                                4                         4
# 420                                3                         2
# 421                                3                         3
# 422                                2                         2
# 423                                2                         2
# 424                                4                         4
# 425                                4                         3
# 426                                3                         3
# 427                                4                         4
# 428                                4                         4
# 429                                3                         3
# 430                                3                         3
# 431                                4                         4
# 432                                3                         3
# 433                                4                         3
# 434                                3                         3
# 435                                2                         2
# 436                                4                         3
# 437                                4                         4
# 438                                0                         0
# 439                                4                         4
# 440                                3                         2
# 441                                0                         0
# 442                                4                         4
# 443                                4                         3
# 444                                4                         4
# 445                                2                         2
# 446                                3                         3
# 447                                3                         2
# 448                                1                         1
# 449                                4                         3
# 450                                4                         4
# 451                                4                         4
# 452                                4                         2
# 453                                3                         3
# 454                                4                         3
# 455                                4                         3
# 456                                4                         2
# 457                                4                         4
# 458                                3                         2
# 459                                4                         4
# 460                                4                         4
# 461                                3                         2
# 462                                2                         2
# 463                                2                         3
# 464                                3                         3
# 465                                2                         2
# 466                                4                         4
# 467                                3                         3
# 468                                3                         2
# 469                                4                         2
# 470                                4                         4
# 471                                3                         3
# 472                                3                         3
# 473                                4                         3
# 474                                3                         3
# 475                                3                         2
# 476                                3                         3
# 477                                3                         3
# 478                                3                         3
# 479                                4                         3
# 480                                3                         3
# 481                                3                         3
# 482                                4                         4
# 483                                3                         3
# 484                                2                         2
# 485                                0                         0
# 486                                2                         2
# 487                                3                         3
# 488                                3                         3
# 489                                2                         2
# 490                                3                         3
# 491                                0                         0
# 492                                1                         1
# 493                                4                         3
# 494                                3                         2
# 495                                3                         3
# 496                                2                         2
# 497                                2                         3
# 498                                1                         1
# 499                                2                         2
# 500                                3                         2
# 501                                2                         2
# 502                                1                         1
# 503                                1                         2
# 504                                1                         1
# 505                                1                         2
# 506                                2                         3
# 507                                0                         0
# 508                                3                         2
# 509                                2                         2
# 510                                2                         2
# 511                                2                         3
# 512                                2                         2
# 513                                3                         3
# 514                                1                         1
# 515                                3                         3
# 516                                2                         1
# 517                                2                         2
# 518                                3                         3
# 519                                2                         2
# 520                                3                         3
# 521                                3                         3
# 522                                3                         3
# 523                                3                         3
# 524                                2                         3
# 525                                3                         3
# 526                                2                         2
# 527                                3                         2
# 528                                3                         3
# 529                                3                         2
# 530                                3                         3
# 531                                3                         3
# 532                                3                         3
# 533                                2                         2
# 534                                3                         3
# 535                                3                         3
# 536                                2                         2
# 537                                3                         2
# 538                                3                         3
# 539                                2                         2
# 540                                3                         3
# 541                                3                         2
# 542                                3                         3
# 543                                2                         2
# 544                                2                         2
# 545                                2                         3
# 546                                2                         3
# 547                                2                         3
# 548                                3                         3
# 549                                2                         2
# 550                                4                         4
# 551                                3                         3
# 552                                4                         4
# 553                                4                         4
#
#      D.Clinical Trial Confidence  D.Chip Belief  D.Mandatory Belief  \
# 0                              4              4                   4
# 1                              4              4                   2
# 2                              3              4                   3
# 3                              3              4                   3
# 4                              2              4                   2
# 5                              2              4                   2
# 6                              4              4                   3
# 7                              4              0                   4
# 8                              2              3                   2
# 9                              4              4                   4
# 10                             3              4                   3
# 11                             2              4                   3
# 12                             3              4                   3
# 13                             3              3                   2
# 14                             1              4                   2
# 15                             1              3                   2
# 16                             3              4                   3
# 17                             3              4                   3
# 18                             3              4                   2
# 19                             2              2                   2
# 20                             3              4                   1
# 21                             4              4                   1
# 22                             2              3                   2
# 23                             3              4                   3
# 24                             2              4                   2
# 25                             2              3                   2
# 26                             3              4                   3
# 27                             4              4                   1
# 28                             3              4                   3
# 29                             1              2                   1
# 30                             3              4                   3
# 31                             3              3                   3
# 32                             2              2                   2
# 33                             4              4                   2
# 34                             3              4                   3
# 35                             3              4                   2
# 36                             3              2                   2
# 37                             4              4                   3
# 38                             3              4                   3
# 39                             3              4                   4
# 40                             4              4                   4
# 41                             4              4                   3
# 42                             2              4                   2
# 43                             4              4                   4
# 44                             0              4                   0
# 45                             2              4                   2
# 46                             4              4                   4
# 47                             3              4                   4
# 48                             4              4                   3
# 49                             4              4                   4
# 50                             3              1                   3
# 51                             2              3                   2
# 52                             3              4                   3
# 53                             0              2                   0
# 54                             3              4                   2
# 55                             4              4                   4
# 56                             2              4                   2
# 57                             0              4                   0
# 58                             3              4                   0
# 59                             2              3                   1
# 60                             3              4                   3
# 61                             3              4                   4
# 62                             3              4                   2
# 63                             4              4                   2
# 64                             2              2                   2
# 65                             3              3                   4
# 66                             3              4                   3
# 67                             3              4                   2
# 68                             3              4                   2
# 69                             4              3                   4
# 70                             3              4                   3
# 71                             3              4                   3
# 72                             2              2                   2
# 73                             2              4                   2
# 74                             3              4                   4
# 75                             3              4                   4
# 76                             2              4                   4
# 77                             3              1                   3
# 78                             3              3                   2
# 79                             4              4                   4
# 80                             3              4                   4
# 81                             4              4                   4
# 82                             4              4                   4
# 83                             3              4                   3
# 84                             4              4                   3
# 85                             3              3                   1
# 86                             4              4                   4
# 87                             3              4                   1
# 88                             4              4                   1
# 89                             3              4                   2
# 90                             4              4                   4
# 91                             3              1                   3
# 92                             3              4                   3
# 93                             4              4                   3
# 94                             3              4                   3
# 95                             4              4                   4
# 96                             4              4                   3
# 97                             4              4                   2
# 98                             3              3                   3
# 99                             3              4                   3
# 100                            4              4                   3
# 101                            3              4                   3
# 102                            3              3                   4
# 103                            3              4                   3
# 104                            1              3                   1
# 105                            3              4                   3
# 106                            3              4                   2
# 107                            3              4                   3
# 108                            3              4                   2
# 109                            3              3                   2
# 110                            3              1                   2
# 111                            4              4                   3
# 112                            4              4                   4
# 113                            3              4                   3
# 114                            2              2                   2
# 115                            2              4                   4
# 116                            3              4                   0
# 117                            3              4                   3
# 118                            2              2                   2
# 119                            2              4                   2
# 120                            2              2                   2
# 121                            1              2                   1
# 122                            0              4                   0
# 123                            4              0                   4
# 124                            2              2                   2
# 125                            3              3                   3
# 126                            2              3                   3
# 127                            2              3                   3
# 128                            2              4                   3
# 129                            4              4                   4
# 130                            2              2                   2
# 131                            1              2                   0
# 132                            3              3                   1
# 133                            2              2                   1
# 134                            3              3                   2
# 135                            2              3                   2
# 136                            3              4                   1
# 137                            3              4                   3
# 138                            2              3                   3
# 139                            2              3                   1
# 140                            2              3                   1
# 141                            3              2                   3
# 142                            1              3                   2
# 143                            3              4                   2
# 144                            2              3                   3
# 145                            3              3                   3
# 146                            1              4                   1
# 147                            2              4                   1
# 148                            2              3                   1
# 149                            2              2                   2
# 150                            2              3                   2
# 151                            1              3                   2
# 152                            1              3                   2
# 153                            2              3                   2
# 154                            2              4                   2
# 155                            2              2                   2
# 156                            2              2                   2
# 157                            4              4                   4
# 158                            4              0                   4
# ...
# 247       0        0            0               1
# 248       0        0            0               1
# 249       0        0            0               0
# 250       0        0            2               0
# 251       0        0            0               1
# 252       0        0            0               1
# 253       0        0            0               1
# 254       0        0            0               1
# 255       0        0            1               1
# 256       0        1            0               1
# 257       0        0            0               1
# 258       0        0            1               0
# 259       0        0            0               0
# 260       0        0            0               1
# 261       0        0            0               1
# 262       0        0            0               1
# 263       0        0            0               0
# 264       0        0            0               1
# 265       0        0            3               1
# 266       0        0            0               0
# 267       1        0            0               1
# 268       0        0            0               1
# 269       0        0            0               1
# 270       0        0            0               1
# 271       0        0            0               1
# 272       0        1            0               0
# 273       0        0            0               1
# 274       0        0            2               1
# 275       0        0            0               1
# 276       0        0            0               1
# 277       0        0            0               0
# 278       0        0            0               1
# 279       0        0            0               0
# 280       0        0            4               0
# 281       0        0            0               0
# 282       0        0            0               1
# 283       0        0            0               1
# 284       0        0            0               1
# 285       0        0            2               1
# 286       0        0            0               1
# 287       0        0            0               1
# 288       0        0            0               0
# 289       1        0            0               0
# 290       0        0            0               0
# 291       0        0            0               1
# 292       0        0            0               1
# 293       0        0            0               0
# 294       0        0            0               1
# 295       0        0            0               0
# 296       0        1            0               1
# 297       1        1            0               0
# 298       0        0            0               1
# 299       0        0            0               1
# 300       0        0            0               1
# 301       0        1            0               0
# 302       0        0            0               1
# 303       0        0            0               1
# 304       0        0            0               0
# 305       0        0            0               0
# 306       0        0            0               0
# 307       0        0            0               1
# 308       0        0            0               1
# 309       0        0            1               1
# 310       0        0            0               1
# 311       0        0            0               1
# 312       0        0            1               1
# 313       0        0            0               1
# 314       0        0            0               1
# 315       0        0            1               1
# 316       0        0            0               0
# 317       0        0            3               0
# 318       0        0            0               1
# 319       0        1            0               0
# 320       0        0            0               0
# 321       1        0            0               1
# 322       0        0            0               1
# 323       0        0            0               0
# 324       0        1            0               1
# 325       0        0            0               1
# 326       0        0            0               1
# 327       0        0            0               0
# 328       0        0            0               1
# 329       0        0            0               1
# 330       1        1            0               1
# 331       0        0            0               0
# 332       0        0            1               1
# 333       0        0            0               1
# 334       0        1            0               1
# 335       1        1            0               1
# 336       0        0            0               0
# 337       0        0            0               0
# 338       0        0            0               1
# 339       0        1            0               0
# 340       0        0            0               0
# 341       0        0            0               0
# 342       1        0            0               0
# 343       0        0            0               0
# 344       0        0            0               0
# 345       0        0            0               1
# 346       0        0            0               0
# 347       0        0            0               1
# 348       0        0            0               0
# 349       0        0            0               0
# 350       0        0            2               0
# 351       0        0            0               1
# 352       0        0            0               1
# 353       0        0            0               1
# 354       0        0            0               0
# 355       0        0            0               1
# 356       0        0            0               1
# 357       0        0            0               1
# 358       0        0            0               1
# 359       0        0            0               0
# 360       0        0            2               1
# 361       0        0            0               0
# 362       0        1            0               0
# 363       0        0            0               1
# 364       0        0            0               1
# 365       0        0            0               0
# 366       0        0            0               1
# 367       0        0            0               1
# 368       0        0            0               0
# 369       0        0            0               1
# 370       0        0            0               1
# 371       0        1            0               0
# 372       0        1            0               1
# 373       0        0            0               0
# 374       0        0            0               1
# 375       0        1            0               0
# 376       0        0            0               1
# 377       0        0            0               1
# 378       0        0            0               1
# 379       0        0            0               1
# 380       0        0            0               0
# 381       0        0            0               1
# 382       0        0            0               1
# 383       0        0            0               0
# 384       0        0            0               1
# 385       0        0            0               1
# 386       0        1            0               0
# 387       0        0            0               1
# 388       0        0            0               1
# 389       0        1            0               1
# 390       0        0            0               1
# 391       1        1            0               0
# 392       0        0            0               1
# 393       0        0            0               0
# 394       1        1            0               1
# 395       0        0            0               1
# 396       0        0            2               1
# 397       0        0            0               1
# 398       0        0            0               1
# 399       0        0            2               1
# 400       0        0            0               1
# 401       0        0            0               0
# 402       0        0            0               1
# 403       0        1            0               0
# 404       0        0            0               1
# 405       0        0            0               1
# 406       0        0            0               1
# 407       0        0            0               1
# 408       0        0            1               1
# 409       0        0            1               1
# 410       0        0            0               1
# 411       0        0            1               0
# 412       0        0            0               1
# 413       0        0            0               1
# 414       0        0            0               1
# 415       0        0            0               0
# 416       0        0            0               1
# 417       0        1            0               0
# 418       0        0            0               0
# 419       0        1            0               1
# 420       0        0            0               1
# 421       0        1            1               1
# 422       0        1            0               0
# 423       0        0            0               0
# 424       0        0            0               1
# 425       0        0            0               1
# 426       0        0            0               1
# 427       0        0            0               1
# 428       0        1            0               1
# 429       0        0            0               0
# 430       0        0            0               1
# 431       0        0            0               1
# 432       0        0            1               0
# 433       0        0            0               0
# 434       0        0            0               1
# 435       0        0            0               0
# 436       0        0            1               1
# 437       0        0            3               1
# 438       1        1            0               0
# 439       0        0            1               1
# 440       0        1            1               1
# 441       0        1            0               0
# 442       0        0            0               1
# 443       0        0            1               1
# 444       0        0            1               1
# 445       0        0            0               0
# 446       0        0            0               1
# 447       0        1            0               0
# 448       1        1            0               0
# 449       0        0            0               1
# 450       0        0            0               1
# 451       0        0            0               1
# 452       0        0            0               1
# 453       0        0            0               0
# 454       0        0            0               0
# 455       0        0            0               1
# 456       0        0            0               1
# 457       0        0            2               1
# 458       0        0            0               0
# 459       0        1            0               1
# 460       0        0            0               1
# 461       0        0            0               0
# 462       0        0            1               1
# 463       0        1            3               0
# 464       0        0            0               1
# 465       0        0            3               0
# 466       0        0            1               1
# 467       0        0            3               1
# 468       0        0            3               1
# 469       0        0            1               0
# 470       0        0            0               1
# 471       0        0            1               1
# 472       0        1            3               1
# 473       1        1            0               0
# 474       0        1            1               1
# 475       0        0            0               0
# 476       0        0            1               0
# 477       0        0            2               1
# 478       0        1            0               0
# 479       0        0            3               1
# 480       0        0            3               1
# 481       0        0            3               1
# 482       0        0            0               1
# 483       0        0            0               1
# 484       0        0            0               0
# 485       0        1            0               0
# 486       0        0            0               0
# 487       0        0            0               0
# 488       1        1            0               1
# 489       0        0            0               0
# 490       0        0            0               1
# 491       0        0            0               0
# 492       0        0            0               0
# 493       0        0            1               1
# 494       0        0            0               0
# 495       0        1            0               1
# 496       0        0            0               0
# 497       0        1            1               0
# 498       0        0            0               1
# 499       0        0            0               0
# 500       0        0            0               0
# 501       1        1            0               0
# 502       0        0            1               0
# 503       1        1            0               0
# 504       0        1            2               0
# 505       0        0            1               0
# 506       0        0            1               0
# 507       0        1            3               0
# 508       0        0            3               1
# 509       0        1            2               0
# 510       0        1            0               0
# 511       0        0            0               0
# 512       0        1            0               0
# 513       0        0            0               1
# 514       0        0            0               0
# 515       0        0            0               1
# 516       0        0            0               0
# 517       0        0            0               0
# 518       0        0            0               1
# 519       0        0            0               0
# 520       0        0            0               1
# 521       0        0            0               1
# 522       0        0            0               1
# 523       0        0            0               1
# 524       0        0            0               0
# 525       0        0            0               0
# 526       0        0            0               0
# 527       0        0            2               0
# 528       0        0            1               1
# 529       0        0            1               0
# 530       0        0            1               1
# 531       0        0            1               1
# 532       0        0            0               0
# 533       1        0            0               0
# 534       0        1            0               0
# 535       0        0            3               1
# 536       0        1            0               0
# 537       0        0            0               0
# 538       0        0            1               1
# 539       0        0            0               0
# 540       0        1            0               0
# 541       0        0            0               0
# 542       0        0            0               1
# 543       0        0            2               0
# 544       0        0            0               0
# 545       0        0            0               0
# 546       0        0            0               1
# 547       0        0            0               0
# 548       0        0            0               1
# 549       0        0            0               0
# 550       0        0            0               1
# 551       0        1            0               1
# 552       0        0            0               1
# 553       0        1            0               1

# %%
import warnings
import numpy as np

# Suppress overflow warning
warnings.filterwarnings("ignore", category=RuntimeWarning)
np.seterr(over='ignore')
# Out:
# {'divide': 'warn', 'over': 'warn', 'under': 'ignore', 'invalid': 'warn'}

# %%
target=df["C.Non_hesitant"]
features=df.drop('C.Non_hesitant',axis=1)

# %%
# Split data into train and test sets

# Import train_test_split function
from sklearn.model_selection import train_test_split

# Split the dataset into training + development set and test set
x_train, x_test, y_train, y_test = train_test_split(features, target, test_size = 0.2, random_state = 0)

# %% [markdown]
# # RANDOM FOREST

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Random Forest Bagging
model_bagging_rf = BaggingClassifier(estimator=RandomForestClassifier(), n_estimators=10, random_state=7)

# Cross-validation
print("Model: Random Forest")
scores_rf = cross_val_score(model_bagging_rf, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_rf)
print("Mean Accuracy (Validation):", scores_rf.mean())
print("-" * 50)

# Test set evaluation
model_bagging_rf.fit(x_train, y_train)
test_predict_rf = model_bagging_rf.predict(x_test)
print("Random Forest Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_rf))
print("=" * 50)
# Out:
# Model: Random Forest
# Accuracy scores for each fold:  [0.84269663 0.88764045 0.82022472 0.82954545 0.86363636]
# Mean Accuracy (Validation): 0.8487487231869254
# --------------------------------------------------
# Random Forest Bagging - Accuracy (Test): 0.8738738738738738
# ==================================================

# %% [markdown]
# # BAGGING

# %% [markdown]
# NN

# %%
# Import necessary libraries
from sklearn.neural_network import MLPClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Neural Network with one hidden layer of 5 neurons
model_bagging_nn = BaggingClassifier(
    estimator=MLPClassifier(hidden_layer_sizes=(5,10), max_iter=200, random_state=7), 
    n_estimators=10, 
    random_state=7
)

# Cross-validation
print("Model: Neural Network (5 neurons in the hidden layer)")
scores_nn = cross_val_score(model_bagging_nn, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold: ", scores_nn)
print("Mean Accuracy (Validation):", scores_nn.mean())
print("-" * 50)

# Test set evaluation
model_bagging_nn.fit(x_train, y_train)
test_predict_nn = model_bagging_nn.predict(x_test)
print("Neural Network Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_nn))
print("=" * 50)
# Out:
# Model: Neural Network (5 neurons in the hidden layer)
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Accuracy scores for each fold:  [0.82022472 0.74157303 0.78651685 0.76136364 0.79545455]
# Mean Accuracy (Validation): 0.781026557711951
# --------------------------------------------------
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# Neural Network Bagging - Accuracy (Test): 0.8468468468468469
# ==================================================
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(
# /Applications/anaconda3/lib/python3.12/site-packages/sklearn/neural_network/_multilayer_perceptron.py:691: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   warnings.warn(

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Linear SVM Bagging (with probability=True for flexibility)
model_bagging_linear_svm = BaggingClassifier(
    estimator=SVC(kernel='linear', C=0.1, probability=True),
    n_estimators=10,
    random_state=7
)

# Cross-validation
print("Model: Linear SVM (C=0.1)")
scores_linear_svm = cross_val_score(model_bagging_linear_svm, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold:", scores_linear_svm)
print("Mean Accuracy (Validation):", scores_linear_svm.mean())
print("-" * 50)

# Test set evaluation
model_bagging_linear_svm.fit(x_train, y_train)
test_predict_linear_svm = model_bagging_linear_svm.predict(x_test)
print("Linear SVM Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_linear_svm))
print("=" * 50)
# Out:
# Model: Linear SVM (C=0.1)
# Accuracy scores for each fold: [0.86516854 0.88764045 0.84269663 0.81818182 0.86363636]
# Mean Accuracy (Validation): 0.855464759959142
# --------------------------------------------------
# Linear SVM Bagging - Accuracy (Test): 0.8738738738738738
# ==================================================

# %%
from sklearn.svm import SVC
from sklearn.ensemble import BaggingClassifier
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# Polynomial SVM Bagging (with probability=True for flexibility)
model_bagging_poly_svm = BaggingClassifier(
    estimator=SVC(kernel='poly', C=1, degree=3, gamma='scale', probability=True),
    n_estimators=10,
    random_state=7
)

# Cross-validation
print("Model: Polynomial SVM (C=1, degree=3)")
scores_poly_svm = cross_val_score(model_bagging_poly_svm, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold:", scores_poly_svm)
print("Mean Accuracy (Validation):", scores_poly_svm.mean())
print("-" * 50)

# Fit and Test evaluation
model_bagging_poly_svm.fit(x_train, y_train)
test_predict_poly_svm = model_bagging_poly_svm.predict(x_test)
print("Polynomial SVM Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_poly_svm))
print("=" * 50)
# Out:
# Model: Polynomial SVM (C=1, degree=3)
# Accuracy scores for each fold: [0.86516854 0.87640449 0.84269663 0.81818182 0.86363636]
# Mean Accuracy (Validation): 0.8532175689479061
# --------------------------------------------------
# Polynomial SVM Bagging - Accuracy (Test): 0.8828828828828829
# ==================================================

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# RBF SVM Bagging (with probability=True for flexibility)
model_bagging_rbf_svm = BaggingClassifier(
    estimator=SVC(kernel='rbf', C=10, gamma='scale', probability=True),
    n_estimators=10,
    random_state=7
)

# Cross-validation
print("Model: RBF SVM (C=10, gamma='scale')")
scores_rbf_svm = cross_val_score(model_bagging_rbf_svm, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold:", scores_rbf_svm)
print("Mean Accuracy (Validation):", scores_rbf_svm.mean())
print("-" * 50)

# Test set evaluation
model_bagging_rbf_svm.fit(x_train, y_train)
test_predict_rbf_svm = model_bagging_rbf_svm.predict(x_test)
print("RBF SVM Bagging - Accuracy (Test):", metrics.accuracy_score(y_test, test_predict_rbf_svm))
print("=" * 50)
# Out:
# Model: RBF SVM (C=10, gamma='scale')
# Accuracy scores for each fold: [0.87640449 0.85393258 0.85393258 0.81818182 0.84090909]
# Mean Accuracy (Validation): 0.8486721144024516
# --------------------------------------------------
# RBF SVM Bagging - Accuracy (Test): 0.8738738738738738
# ==================================================

# %% [markdown]
# # Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np

# Define the Gradient Boosting classifier
gbc = GradientBoostingClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Cross-validation
cv_scores = cross_val_score(gbc, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold (CV): ", cv_scores)
print("Mean Accuracy (Validation): {:.4f}".format(cv_scores.mean()))
print("-" * 50)

# Fit the model on the full training data
gbc.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred = gbc.predict(x_test)
accuracy = accuracy_score(y_test, y_test_pred)

# Print evaluation metrics
print(f'Accuracy (Test): {accuracy:.4f}')
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred))
print('Classification Report:')
print(classification_report(y_test, y_test_pred))
print("=" * 50)
# Out:
# Accuracy scores for each fold (CV):  [0.82022472 0.84269663 0.78651685 0.81818182 0.86363636]
# Mean Accuracy (Validation): 0.8263
# --------------------------------------------------
# Accuracy (Test): 0.8739
# Confusion Matrix:
# [[37  8]
#  [ 6 60]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.86      0.82      0.84        45
#            1       0.88      0.91      0.90        66
#
#     accuracy                           0.87       111
#    macro avg       0.87      0.87      0.87       111
# weighted avg       0.87      0.87      0.87       111
#
# ==================================================

# %%
import xgboost as xgb
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import numpy as np

# Define the XGBoost classifier
xgb_clf = xgb.XGBClassifier(n_estimators=100, learning_rate=0.1, max_depth=3, random_state=42)

# Cross-validation
cv_scores = cross_val_score(xgb_clf, x_train, y_train, cv=5, scoring='accuracy')
print("Accuracy scores for each fold (CV): ", cv_scores)
print("Mean Accuracy (Validation): {:.4f}".format(cv_scores.mean()))
print("-" * 50)

# Fit the model on the full training data
xgb_clf.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred = xgb_clf.predict(x_test)
accuracy = accuracy_score(y_test, y_test_pred)

# Print evaluation metrics
print(f'Accuracy (Test): {accuracy:.4f}')
print('Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred))
print('Classification Report:')
print(classification_report(y_test, y_test_pred))
print("=" * 50)
# Out:
# Accuracy scores for each fold (CV):  [0.83146067 0.85393258 0.83146067 0.80681818 0.86363636]
# Mean Accuracy (Validation): 0.8375
# --------------------------------------------------
# Accuracy (Test): 0.8649
# Confusion Matrix:
# [[37  8]
#  [ 7 59]]
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.84      0.82      0.83        45
#            1       0.88      0.89      0.89        66
#
#     accuracy                           0.86       111
#    macro avg       0.86      0.86      0.86       111
# weighted avg       0.86      0.86      0.86       111
#
# ==================================================

# %% [markdown]
# # ADABOOSTING

# %% [markdown]
# rbf

# %%
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Define the RBF SVM base estimator with updated parameters
rbf_svm = SVC(kernel='rbf', probability=True, C=10, gamma='scale', random_state=7)

# AdaBoost with RBF SVM
ada_rbf_svm = AdaBoostClassifier(estimator=rbf_svm, n_estimators=10, random_state=7)

# Cross-validation
cv_scores_rbf_svm = cross_val_score(ada_rbf_svm, x_train, y_train, cv=5, scoring='accuracy')
print("RBF SVM - Accuracy scores for each fold (CV): ", cv_scores_rbf_svm)
print("RBF SVM - Mean Accuracy (Validation): {:.4f}".format(cv_scores_rbf_svm.mean()))
print("-" * 50)

# Fit the model on the full training data
ada_rbf_svm.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred_rbf_svm = ada_rbf_svm.predict(x_test)
accuracy_rbf_svm = accuracy_score(y_test, y_test_pred_rbf_svm)

# Print evaluation metrics
print(f'RBF SVM - Accuracy (Test): {accuracy_rbf_svm:.4f}')
print('RBF SVM - Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred_rbf_svm))
print('RBF SVM - Classification Report:')
print(classification_report(y_test, y_test_pred_rbf_svm))
print("=" * 50)
# Out:
# RBF SVM - Accuracy scores for each fold (CV):  [0.82022472 0.79775281 0.79775281 0.77272727 0.82954545]
# RBF SVM - Mean Accuracy (Validation): 0.8036
# --------------------------------------------------
# RBF SVM - Accuracy (Test): 0.8288
# RBF SVM - Confusion Matrix:
# [[41  4]
#  [15 51]]
# RBF SVM - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.73      0.91      0.81        45
#            1       0.93      0.77      0.84        66
#
#     accuracy                           0.83       111
#    macro avg       0.83      0.84      0.83       111
# weighted avg       0.85      0.83      0.83       111
#
# ==================================================

# %%
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Define the Linear SVM base estimator with updated parameters
linear_svm = SVC(kernel='linear', probability=True, C=0.1, random_state=7)

# AdaBoost with Linear SVM
ada_linear_svm = AdaBoostClassifier(estimator=linear_svm, n_estimators=10, random_state=7)

# Cross-validation
cv_scores_linear_svm = cross_val_score(ada_linear_svm, x_train, y_train, cv=5, scoring='accuracy')
print("Linear SVM - Accuracy scores for each fold (CV): ", cv_scores_linear_svm)
print("Linear SVM - Mean Accuracy (Validation): {:.4f}".format(cv_scores_linear_svm.mean()))
print("-" * 50)

# Fit the model on the full training data
ada_linear_svm.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred_linear_svm = ada_linear_svm.predict(x_test)
accuracy_linear_svm = accuracy_score(y_test, y_test_pred_linear_svm)

# Print evaluation metrics
print(f'Linear SVM - Accuracy (Test): {accuracy_linear_svm:.4f}')
print('Linear SVM - Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred_linear_svm))
print('Linear SVM - Classification Report:')
print(classification_report(y_test, y_test_pred_linear_svm))
print("=" * 50)
# Out:
# Linear SVM - Accuracy scores for each fold (CV):  [0.64044944 0.66292135 0.58426966 0.71590909 0.625     ]
# Linear SVM - Mean Accuracy (Validation): 0.6457
# --------------------------------------------------
# Linear SVM - Accuracy (Test): 0.6667
# Linear SVM - Confusion Matrix:
# [[41  4]
#  [33 33]]
# Linear SVM - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.55      0.91      0.69        45
#            1       0.89      0.50      0.64        66
#
#     accuracy                           0.67       111
#    macro avg       0.72      0.71      0.66       111
# weighted avg       0.75      0.67      0.66       111
#
# ==================================================

# %%
import numpy as np
from sklearn.ensemble import AdaBoostClassifier
from sklearn.svm import SVC
from sklearn.model_selection import cross_val_score
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report

# Define the Polynomial SVM base estimator
poly_svm = SVC(kernel='poly', C=1, degree=3, gamma='scale', probability=True, random_state=7)

# AdaBoost with Polynomial SVM
ada_poly_svm = AdaBoostClassifier(estimator=poly_svm, n_estimators=10, random_state=7)

# Cross-validation
cv_scores_poly_svm = cross_val_score(ada_poly_svm, x_train, y_train, cv=5, scoring='accuracy')
print("Polynomial SVM - Accuracy scores for each fold (CV): ", cv_scores_poly_svm)
print("Polynomial SVM - Mean Accuracy (Validation): {:.4f}".format(cv_scores_poly_svm.mean()))
print("-" * 50)

# Fit the model on the full training data
ada_poly_svm.fit(x_train, y_train)

# Evaluate the model on the test data
y_test_pred_poly_svm = ada_poly_svm.predict(x_test)
accuracy_poly_svm = accuracy_score(y_test, y_test_pred_poly_svm)

# Print evaluation metrics
print(f'Polynomial SVM - Accuracy (Test): {accuracy_poly_svm:.4f}')
print('Polynomial SVM - Confusion Matrix:')
print(confusion_matrix(y_test, y_test_pred_poly_svm))
print('Polynomial SVM - Classification Report:')
print(classification_report(y_test, y_test_pred_poly_svm))
print("=" * 50)
# Out:
# Polynomial SVM - Accuracy scores for each fold (CV):  [0.80898876 0.82022472 0.84269663 0.76136364 0.81818182]
# Polynomial SVM - Mean Accuracy (Validation): 0.8103
# --------------------------------------------------
# Polynomial SVM - Accuracy (Test): 0.8198
# Polynomial SVM - Confusion Matrix:
# [[41  4]
#  [16 50]]
# Polynomial SVM - Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.72      0.91      0.80        45
#            1       0.93      0.76      0.83        66
#
#     accuracy                           0.82       111
#    macro avg       0.82      0.83      0.82       111
# weighted avg       0.84      0.82      0.82       111
#
# ==================================================

# %%
from sklearn.ensemble import BaggingClassifier, AdaBoostClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import cross_val_score
from sklearn import metrics

# KNN (k=23) - Bagging only
model_bagging_knn = BaggingClassifier(
    estimator=KNeighborsClassifier(n_neighbors=9),
    n_estimators=10,
    random_state=7
)
print("Model: KNN (k=23) - Bagging")
scores = cross_val_score(model_bagging_knn, x_train, y_train, cv=5, scoring='accuracy')
print("Validation Accuracy:", scores.mean())
model_bagging_knn.fit(x_train, y_train)
print("Test Accuracy:", metrics.accuracy_score(y_test, model_bagging_knn.predict(x_test)))
print("=" * 50)

# Decision Tree (depth=4) - Bagging
model_bagging_dt = BaggingClassifier(
    estimator=DecisionTreeClassifier(max_depth=3, random_state=7),
    n_estimators=10,
    random_state=7
)
print("Model: Decision Tree (depth=4) - Bagging")
scores = cross_val_score(model_bagging_dt, x_train, y_train, cv=5, scoring='accuracy')
print("Validation Accuracy:", scores.mean())
model_bagging_dt.fit(x_train, y_train)
print("Test Accuracy:", metrics.accuracy_score(y_test, model_bagging_dt.predict(x_test)))
print("=" * 50)

# Decision Tree (depth=4) - AdaBoost
model_adaboost_dt = AdaBoostClassifier(
    estimator=DecisionTreeClassifier(max_depth=3, random_state=7),
    n_estimators=50,
    random_state=7
)
print("Model: Decision Tree (depth=3) - AdaBoost")
scores = cross_val_score(model_adaboost_dt, x_train, y_train, cv=5, scoring='accuracy')
print("Validation Accuracy:", scores.mean())
model_adaboost_dt.fit(x_train, y_train)
print("Test Accuracy:", metrics.accuracy_score(y_test, model_adaboost_dt.predict(x_test)))
print("=" * 50)

# MultinomialNB - Bagging only
model_bagging_mnb = BaggingClassifier(
    estimator=MultinomialNB(),
    n_estimators=10,
    random_state=7
)
print("Model: MultinomialNB - Bagging")
scores = cross_val_score(model_bagging_mnb, x_train, y_train, cv=5, scoring='accuracy')
print("Validation Accuracy:", scores.mean())
model_bagging_mnb.fit(x_train, y_train)
print("Test Accuracy:", metrics.accuracy_score(y_test, model_bagging_mnb.predict(x_test)))
print("=" * 50)
# Out:
# Model: KNN (k=23) - Bagging
# Validation Accuracy: 0.8351889683350358
# Test Accuracy: 0.8828828828828829
# ==================================================
# Model: Decision Tree (depth=4) - Bagging
# Validation Accuracy: 0.8533197139938713
# Test Accuracy: 0.8648648648648649
# ==================================================
# Model: Decision Tree (depth=3) - AdaBoost
# Validation Accuracy: 0.8306945863125639
# Test Accuracy: 0.8378378378378378
# ==================================================
# Model: MultinomialNB - Bagging
# Validation Accuracy: 0.7584780388151174
# Test Accuracy: 0.7837837837837838
# ==================================================
